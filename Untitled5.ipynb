# %% [markdown]
# **DAX Functions in Power BI**

# %% [markdown]
# 1  .  totalprice = 'Table'[Quantity] * 'Table'[unit price]
#
# 2  . Discountedprice = 'Table'[totalprice] * (1 - 'Table'[discount%])
#
# 3  . AOV = AVERAGE( 'Table'[Totalprice])
#
# 4  . TOTALYTD(SUM('Table[Totalprice]),
#      'Datetable'[Date])
#
# 5  . RANK(ALL('Product'[product]),
#      CALCULATE(SUM('Table'[Totalprice])))
#
# 6  . Order class = IF('Table'[Totalprice]>2000,"High value","Low Value")
#
#
# 7  . CALCULATE(SUM('Table'[Totalprice]),
#      'Table'[Channel] = "Online")
#
# 8  . DATEDIFF(MAX('Table'[Order Date]),TODAY(),DAY)
